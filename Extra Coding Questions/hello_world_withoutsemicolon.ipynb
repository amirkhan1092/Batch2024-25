# %% [markdown]
# ### Problem Statement:
#
# Write a program in Java to print "Hello, World!" without using a semicolon (`;`) anywhere in your code.
#
# ---
#
# ### Input Format:
# - There is no input for this program.
#
# ---
#
# ### Output Format:
# - A single line of output:
# ```plaintext
# Hello, World!
# ```
#
# ---
#
# ### Constraints:
# - The program must not use a semicolon (`;`) for any statement, including print statements.
# - The output must match the exact format shown above.
#
# ---
#
# ### Example:
#
# #### Example 1:
# **Input:**
# ```plaintext
# (No input)
# ```
#
# **Output:**
# ```plaintext
# Hello, World!
# ```
#
# ---
#
# ### Hint:
# - Think of alternatives to terminate or execute statements without explicitly using a semicolon.
#
# ---
#
# ### Expected Solution:
#
# You can achieve this by using conditional statements, loops, or other constructs like `if`, `while`, or `for`. Here's an example of how the solution might look:
#
# ```java
# public class Main {
#     public static void main(String[] args) {
#         if (System.out.printf("Hello, World!") != null) {
#         }
#     }
# }
# ```
#
# ---
#
# ### Constraints on the Problem:
# 1. Ensure that the code is strictly Java-compliant.
# 2. Avoid using unconventional or undefined behavior.
