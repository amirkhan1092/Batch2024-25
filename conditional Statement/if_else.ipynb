# %%
# if-else
'''
syntax
if test_expression:
    statements
else:
    statements
'''

# %%
# Example1
num = 11
if num % 2 == 0:
    print(num, 'is Even')
else:    
    print(num, 'is Odd')
# Out:
# 11 is Odd
